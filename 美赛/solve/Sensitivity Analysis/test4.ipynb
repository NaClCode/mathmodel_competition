# %%
# -0.04 490
# -0.03 600
# -0.02 860
# -0.01 1400
import pylab as plt
plt.plot([-0.005, -0.003, -0.001, 0.001, 0.003, 0.005], [800, 4300, 7000, 8000, 2400, 460], 'ro')
plt.xlabel('alpha')
plt.ylabel('Time')
plt.savefig(fname = 'Sensitivity_Analysis_2.jpg', dpi = 500, bbox_inches = 'tight')
