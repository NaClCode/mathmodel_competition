# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
from scipy import stats
import warnings
warnings.filterwarnings("ignore")

df1 = pd.read_csv('time/time1.csv')
print(df1.qty)
sns.distplot(df1.qty)
matplotlib.rcParams['font.sans-serif'] = ['SimHei']
matplotlib.rcParams['axes.unicode_minus'] = False
plt.savefig(fname = 'qty分布.png', dpi = 500, bbox_inches = 'tight', pad_inches = 0.0)
plt.show()
# Out:
# 0       6
# 1       9
# 2       6
# 3       2
# 4       9
#        ..
# 161     7
# 162     9
# 163     4
# 164     8
# 165    10
# Name: qty, Length: 166, dtype: int64

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
# stats.boxcox_normplot(df1.qty + 1, -20, 20,plot = ax)
# plt.axvline(x = stats.boxcox_normmax(df1.qty + 1),color = "#D86457")
# plt.show()

print(stats.boxcox_normmax(df1.qty + 1))
x = stats.boxcox(df1.qty + 1,stats.boxcox_normmax(df1.qty + 1))
sns.distplot(x)
plt.xlabel('qty')
plt.savefig(fname = 'qty分布BOXCOX转换.png', dpi = 500, bbox_inches = 'tight', pad_inches = 0.0)
df=pd.DataFrame(x,columns=['转换'])
print(df)
# Out:
# 0.3028804766107474
#            转换
# 0    2.650772
# 1    3.329828
# 2    2.650772
# 3    1.303471
# 4    3.329828
# ..        ...
# 161  2.896446
# 162  3.329828
# 163  2.074044
# 164  3.121548
# 165  3.524052
#
# [166 rows x 1 columns]
